# %% [markdown]
# ## Exercices plus court chemin correction

# %% [markdown]
# ![image.png](attachment:87cf1249-b155-4ac1-8a7c-589131133f23.png)

# %% [markdown]
# I RIP : nombre de sauts entre deux routeurs,
# I OSPF : coût d’une liaison.

# %% [markdown]
# ## Bellman ford
# ![image.png](attachment:169d183d-e52b-42c9-9c49-95e12f8299bc.png)

# %% [markdown]
# ![image.png](attachment:d4468196-370f-4ace-864e-ce622acbadaa.png)

# %% [markdown]
# ![image.png](attachment:838afb39-1d3e-4af2-9c64-131911b6a398.png)

# %% [markdown]
# coût de 5 → bande-passante 20Mbit/s

# %% [markdown]
# ![image.png](attachment:425c29a8-6023-4b19-8843-a29a8a5dcb37.png)
